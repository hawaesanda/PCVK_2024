# %% [markdown]
# <a href="https://colab.research.google.com/github/hawaesanda/PCVK_2024/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang
# sudah ada. Hasil nya berupa output gambar yang sudah di plot dengan matplotlib untuk
# mengetahui ukuran panjang dan lebar dari gambar tersebut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Image/Kitten.jpg')
plt.imshow(img)

# %% [markdown]
# OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan
# citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Image/Kitten.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# simpan file image
# cv.imwrite('/content/drive/MyDrive/PCVK/Image/Kitten_flip.jpg', img5)

# tampilkan plot dengan ukuran canvas lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image
# dengan tipe data int16.

# %%
black_img = np.zeros((512,512,3), dtype='uint8')
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
cv.rectangle(black_img,pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2
# yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
# tertulis pada kode program.

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='HELLO', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros((512,512,3), dtype='int32')
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menujukan bahwa setiap titik dibuat 3 chanenel yang mewakili RGB
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ### **ASSIGNMENT**

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
red_blue_img = img3
red_blue_img[:, :, 1] = 0  # Set kanal hijau (Green) menjadi nol
plt.title('Red-Blue Channel')
plt.imshow(red_blue_img)

# %%
img4 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
green_blue_img = img4
green_blue_img[:, :, 0] = 0  # Set kanal merah (Red) menjadi nol
plt.title('Green-Blue Channel')
plt.imshow(green_blue_img)

# %%
cropped_img = img3[20:115, 25:120]
plt.title('Tampilkan image baris 20-115, kolom 25-120')
plt.imshow(cropped_img)

# %%
img5 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
red_channel_img = img5
cropped_red_channel_img = red_channel_img[5:30, :, 0]
plt.title('Channel Red Baris 5-30, Semua Kolom')
plt.imshow(cropped_red_channel_img)

# %%
img6 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Kotak dengan ukuran dan warna berbeda
cv.rectangle(img6, pt1=(5, 50), pt2=(50, 5), color=(255, 0, 0), thickness=5)
cv.rectangle(img6, pt1=(50, 100), pt2=(100, 50), color=(255, 255, 0), thickness=5)
cv.rectangle(img6, pt1=(100, 150), pt2=(150, 100), color=(0, 255, 0), thickness=5)
cv.rectangle(img6, pt1=(150, 200), pt2=(200, 150), color=(0, 0, 255), thickness=5)
cv.rectangle(img6, pt1=(200, 250), pt2=(250, 200), color=(0, 255, 255), thickness=5)
# Menampilkan output
plt.title('5 Kotak dengan ukuran dan warna yang berbeda')
plt.imshow(img6)

# %%
img7 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
plt.title('Image dengan posisi terbalik')
plt.imshow(img7)

# %%
img4 = cv.imread('/content/drive/MyDrive/PCVK/Image/Me.jpg')
img5 = cv.cvtColor(img4, cv.COLOR_BGR2RGB)

cv.circle(img5, center=(900, 900), radius=100, color=(255, 0, 0), thickness=10)
cv.rectangle(img5, pt1=(1050, 700), pt2=(700, 1050), color=(0, 255, 0), thickness=10)
plt.title('Buat rectangle dan circle pada bagian wajah foto anda saat beraktifitas')
plt.imshow(img5)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img6 = cv.imread('/content/drive/MyDrive/PCVK/Image/Kitten.jpg')
img7 = cv.cvtColor(img6, cv.COLOR_BGR2RGB)
cv.rectangle(img7, pt1=(10, 270), pt2=(50,235), color=(255, 255, 0), thickness=5)
plt.title('Image kitten dengan rectangle di sudut bawah kiri')
plt.imshow(img7)
